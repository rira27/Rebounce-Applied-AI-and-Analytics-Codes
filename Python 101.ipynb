# %% [markdown]
# <a href="https://colab.research.google.com/github/rira27/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python%20101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 starting")
# Out:
# MP1 starting

# %% [markdown]
# **Problem 1 · The Introduction Card**

# %%
# Basic details
name = "Rishika Mehta"
city = "Udaipur"
year_of_birth = 1997

# Computing age
current_year = 2026
age = current_year - year_of_birth

print("Hi, I am", name, "from", city, ".This year I turn", age)
# Out:
# Hi, I am Rishika Mehta from Udaipur .This year I turn 29
